# %% [markdown]
# # Welcome To My Music Generation Project

# %% [markdown]
# ## Step 1: Install django.

# %%
# !pip install django
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting django
#   Downloading Django-3.2.16-py3-none-any.whl (7.9 MB)
#      |████████████████████████████████| 7.9 MB 22.9 MB/s
# Requirement already satisfied: sqlparse>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from django) (0.4.2)
# Collecting asgiref<4,>=3.3.2
#   Downloading asgiref-3.5.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from django) (2022.2.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from asgiref<4,>=3.3.2->django) (4.1.1)
# Installing collected packages: asgiref, django
# Successfully installed asgiref-3.5.2 django-3.2.16

# %% [markdown]
# ## Step 2: Clone my music generation project from my github.

# %%
# !git clone https://github.com/jerry762/MusicGenerator.git
# Out:
# Cloning into 'MusicGenerator'...
# remote: Enumerating objects: 221, done.
# remote: Counting objects: 100% (221/221), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 221 (delta 75), reused 189 (delta 43), pack-reused 0
# Receiving objects: 100% (221/221), 23.51 MiB | 31.06 MiB/s, done.
# Resolving deltas: 100% (75/75), done.

# %% [markdown]
# ## Step 3: Move to the directory which have a manage.py file.

# %%
# %cd MusicGenerator/portfolio/
# %ls
# Out:
# /content/MusicGenerator/portfolio
# manage.py  portfolio/  static_test/  templates/  TestApp/

# %% [markdown]
# ## Step 4: Run this code will give you a link. You Need This Link.

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8000)"))
# Out:
# https://vdhedwxbpto-496ff2e9c6d22116-8000-colab.googleusercontent.com/

# %% [markdown]
# ## Step 5: Run server.

# %%
# !python manage.py runserver 8000  #debug = True, Run this block.
# Out:
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
#
# You have 18 unapplied migration(s). Your project may not work properly until you apply the migrations for app(s): admin, auth, contenttypes, sessions.
# Run 'python manage.py migrate' to apply them.
# October 05, 2022 - 11:38:57
# Django version 3.2.16, using settings 'portfolio.settings'
# Starting development server at http://127.0.0.1:8000/
# Quit the server with CONTROL-C.
# [05/Oct/2022 11:38:59] "GET / HTTP/1.1" 200 12110
# [05/Oct/2022 11:39:00] "GET /static/css/styles.css HTTP/1.1" 200 204772
# [05/Oct/2022 11:39:00] "GET /static/js/scripts.js HTTP/1.1" 200 1176
# [05/Oct/2022 11:39:01] "GET /static/images/head_music.jpg HTTP/1.1" 200 1054272
# [05/Oct/2022 11:39:03] "GET /static/images/music.ico HTTP/1.1" 200 67646
# [05/Oct/2022 11:39:28] "GET /music_dataset/ HTTP/1.1" 200 12834
# [05/Oct/2022 11:39:28] "GET /static/css/styles.css HTTP/1.1" 200 204772
# [05/Oct/2022 11:39:29] "GET /static/js/scripts.js HTTP/1.1" 200 1176
# [05/Oct/2022 11:39:29] "GET /static/images/kern_web.png HTTP/1.1" 200 117396
# [05/Oct/2022 11:39:29] "GET /static/images/Bach.png HTTP/1.1" 200 218320
# [05/Oct/2022 11:39:29] "GET /static/images/Canada_folksong.jpg HTTP/1.1" 200 53897
# [05/Oct/2022 11:39:29] "GET /static/images/Schubert.png HTTP/1.1" 200 171578
# [05/Oct/2022 11:39:29] "GET /static/images/China_folksong.jpg HTTP/1.1" 200 89313
# [05/Oct/2022 11:39:29] "GET /static/images/Stephen_Foster.jpg HTTP/1.1" 200 39253
# [05/Oct/2022 11:39:29] "GET /static/images/Germany_folksong.jpg HTTP/1.1" 200 1888001
# [05/Oct/2022 11:39:30] "GET /static/images/dataset_header.jpg HTTP/1.1" 200 2955972
# [05/Oct/2022 11:39:30] "GET /static/music/China_dataset.mid HTTP/1.1" 200 671
# [05/Oct/2022 11:39:30] "GET /static/music/Canada_dataset.mid HTTP/1.1" 200 718
# [05/Oct/2022 11:39:30] "GET /static/music/Bach_dataset.mid HTTP/1.1" 200 1201
# [05/Oct/2022 11:39:30] "GET /static/music/Schubert_dataset.mid HTTP/1.1" 200 1022
# [05/Oct/2022 11:39:30] "GET /static/music/Germany_dataset.mid HTTP/1.1" 200 295
# [05/Oct/2022 11:39:30] "GET /static/music/Stephen%20Foster_dataset.mid HTTP/1.1" 200 1068
# [05/Oct/2022 11:39:53] "GET /music_generation/ HTTP/1.1" 200 18941
# [05/Oct/2022 11:39:54] "GET /static/css/styles.css HTTP/1.1" 200 204772
# [05/Oct/2022 11:39:54] "GET /static/js/scripts.js HTTP/1.1" 200 1176
# [05/Oct/2022 11:39:55] "GET /static/images/piano_header.jpg HTTP/1.1" 200 3788869
# [05/Oct/2022 11:39:55] "GET /static/music/Germany_lstm.mid HTTP/1.1" 200 818
# [05/Oct/2022 11:39:55] "GET /static/music/Schubert_lstm.mid HTTP/1.1" 200 665
# [05/Oct/2022 11:39:55] "GET /static/music/Canada_lstm.mid HTTP/1.1" 200 1253
# [05/Oct/2022 11:39:55] "GET /static/music/Bach_lstm.mid HTTP/1.1" 200 1304
# [05/Oct/2022 11:39:55] "GET /static/music/Stephen_Foster_lstm.mid HTTP/1.1" 200 867
# [05/Oct/2022 11:39:55] "GET /static/music/Stephen_Foster_transformer.mid HTTP/1.1" 200 1943
# [05/Oct/2022 11:39:55] "GET /static/music/Schubert_transformer.mid HTTP/1.1" 200 1341
# [05/Oct/2022 11:39:55] "GET /static/music/output.mid HTTP/1.1" 200 593
# [05/Oct/2022 11:39:55] "GET /static/music/Bach_transformer.mid HTTP/1.1" 200 2535
# [05/Oct/2022 11:39:55] "GET /static/music/China_lstm.mid HTTP/1.1" 200 656
# [05/Oct/2022 11:39:55] "GET /static/music/Germany_transformer.mid HTTP/1.1" 200 1895
# [05/Oct/2022 11:39:55] "GET /static/music/China_transformer.mid HTTP/1.1" 200 1220
# [05/Oct/2022 11:39:55] "GET /static/music/Canada_transformer.mid HTTP/1.1" 200 2032
# 2022-10-05 11:41:50.761923: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# [05/Oct/2022 11:42:09] "POST /music_generation/predict_lstm HTTP/1.1" 200 18941
# [05/Oct/2022 11:42:09] "GET /static/css/styles.css HTTP/1.1" 200 204772
# [05/Oct/2022 11:42:09] "GET /static/js/scripts.js HTTP/1.1" 200 1176
# [05/Oct/2022 11:42:10] "GET /static/images/piano_header.jpg HTTP/1.1" 200 3788869
# [05/Oct/2022 11:42:10] "GET /static/music/Germany_lstm.mid HTTP/1.1" 200 818
# [05/Oct/2022 11:42:10] "GET /static/music/Canada_lstm.mid HTTP/1.1" 200 1253
# [05/Oct/2022 11:42:10] "GET /static/music/China_lstm.mid HTTP/1.1" 200 656
# [05/Oct/2022 11:42:10] "GET /static/music/China_transformer.mid HTTP/1.1" 200 1220
# [05/Oct/2022 11:42:10] "GET /static/music/Bach_lstm.mid HTTP/1.1" 200 1304
# [05/Oct/2022 11:42:10] "GET /static/music/Stephen_Foster_transformer.mid HTTP/1.1" 200 1943
# [05/Oct/2022 11:42:11] "GET /static/music/Schubert_lstm.mid HTTP/1.1" 200 665
# [05/Oct/2022 11:42:11] "GET /static/music/output.mid HTTP/1.1" 200 593
# [05/Oct/2022 11:42:11] "GET /static/music/Germany_transformer.mid HTTP/1.1" 200 1895
# [05/Oct/2022 11:42:11] "GET /static/music/Stephen_Foster_lstm.mid HTTP/1.1" 200 867
# [05/Oct/2022 11:42:11] "GET /static/music/Schubert_transformer.mid HTTP/1.1" 200 1341
# [05/Oct/2022 11:42:11] "GET /static/music/Bach_transformer.mid HTTP/1.1" 200 2535
# [05/Oct/2022 11:42:11] "GET /static/music/Canada_transformer.mid HTTP/1.1" 200 2032
# [05/Oct/2022 11:43:01] "GET /music_home/ HTTP/1.1" 200 12110
# [05/Oct/2022 11:43:02] "GET /static/css/styles.css HTTP/1.1" 200 204772
# [05/Oct/2022 11:43:02] "GET /static/js/scripts.js HTTP/1.1" 200 1176
# [05/Oct/2022 11:43:03] "GET /static/images/head_music.jpg HTTP/1.1" 200 1054272

# %% [markdown]
# # Development Area (ignore)

# %%
# !python manage.py runserver --insecure 8000 #debug = False, Run this block.
# Out:
# Watching for file changes with StatReloader
# Performing system checks...

# %%
# !python manage.py collectstatic

# %%
# !zip -r /content/project.zip /content/MusicGenerator/portfolio
# Out:
#   adding: content/MusicGenerator/portfolio/ (stored 0%)
#   adding: content/MusicGenerator/portfolio/templates/ (stored 0%)
#   adding: content/MusicGenerator/portfolio/templates/index.html (deflated 67%)
#   adding: content/MusicGenerator/portfolio/templates/dataset.html (deflated 69%)
#   adding: content/MusicGenerator/portfolio/templates/generation.html (deflated 84%)
#   adding: content/MusicGenerator/portfolio/manage.py (deflated 43%)
#   adding: content/MusicGenerator/portfolio/portfolio/ (stored 0%)
#   adding: content/MusicGenerator/portfolio/portfolio/__pycache__/ (stored 0%)
#   adding: content/MusicGenerator/portfolio/portfolio/__pycache__/__init__.cpython-37.pyc (deflated 27%)
#   adding: content/MusicGenerator/portfolio/portfolio/__pycache__/urls.cpython-37.pyc (deflated 46%)
#   adding: content/MusicGenerator/portfolio/portfolio/__pycache__/settings.cpython-37.pyc (deflated 47%)
#   adding: content/MusicGenerator/portfolio/portfolio/__pycache__/wsgi.cpython-37.pyc (deflated 26%)
#   adding: content/MusicGenerator/portfolio/portfolio/wsgi.py (deflated 33%)
#   adding: content/MusicGenerator/portfolio/portfolio/asgi.py (deflated 33%)
#   adding: content/MusicGenerator/portfolio/portfolio/settings.py (deflated 62%)
#   adding: content/MusicGenerator/portfolio/portfolio/__init__.py (stored 0%)
#   adding: content/MusicGenerator/portfolio/portfolio/urls.py (deflated 60%)
#   adding: content/MusicGenerator/portfolio/TestApp/ (stored 0%)
#   adding: content/MusicGenerator/portfolio/TestApp/__pycache__/ (stored 0%)
#   adding: content/MusicGenerator/portfolio/TestApp/__pycache__/models.cpython-37.pyc (deflated 17%)
#   adding: content/MusicGenerator/portfolio/TestApp/__pycache__/__init__.cpython-37.pyc (deflated 21%)
#   adding: content/MusicGenerator/portfolio/TestApp/__pycache__/admin.cpython-37.pyc (deflated 17%)
#   adding: content/MusicGenerator/portfolio/TestApp/__pycache__/apps.cpython-37.pyc (deflated 31%)
#   adding: content/MusicGenerator/portfolio/TestApp/__pycache__/views.cpython-37.pyc (deflated 49%)
#   adding: content/MusicGenerator/portfolio/TestApp/models.py (deflated 5%)
#   adding: content/MusicGenerator/portfolio/TestApp/admin.py (deflated 2%)
#   adding: content/MusicGenerator/portfolio/TestApp/apps.py (deflated 23%)
#   adding: content/MusicGenerator/portfolio/TestApp/lstm_music/ (stored 0%)
#   adding: content/MusicGenerator/portfolio/TestApp/lstm_music/output.mid (deflated 62%)
#   adding: content/MusicGenerator/portfolio/TestApp/views.py (deflated 66%)
#   adding: content/MusicGenerator/portfolio/TestApp/models/ (stored 0%)
#   adding: content/MusicGenerator/portfolio/TestApp/models/model.h5 (deflated 8%)
#   adding: content/MusicGenerator/portfolio/TestApp/tests.py (deflated 3%)
#   adding: content/MusicGenerator/portfolio/TestApp/migrations/ (stored 0%)
#   adding: content/MusicGenerator/portfolio/TestApp/migrations/__pycache__/ (stored 0%)
#   adding: content/MusicGenerator/portfolio/TestApp/migrations/__pycache__/__init__.cpython-37.pyc (deflated 21%)
#   adding: content/MusicGenerator/portfolio/TestApp/migrations/__init__.py (stored 0%)
#   adding: content/MusicGenerator/portfolio/TestApp/__init__.py (stored 0%)
#   adding: content/MusicGenerator/portfolio/TestApp/mapping/ (stored 0%)
#   adding: content/MusicGenerator/portfolio/TestApp/mapping/mapping.json (deflated 66%)
#   adding: content/MusicGenerator/portfolio/static_test/ (stored 0%)
#   adding: content/MusicGenerator/portfolio/static_test/js/ (stored 0%)
#   adding: content/MusicGenerator/portfolio/static_test/js/scripts.js (deflated 60%)
#   adding: content/MusicGenerator/portfolio/static_test/images/ (stored 0%)
#   adding: content/MusicGenerator/portfolio/static_test/images/Germany_folksong.jpg (deflated 0%)
#   adding: content/MusicGenerator/portfolio/static_test/images/head_music.jpg (deflated 1%)
#   adding: content/MusicGenerator/portfolio/static_test/images/Schubert.png (deflated 0%)
#   adding: content/MusicGenerator/portfolio/static_test/images/dataset.jpg (deflated 0%)
#   adding: content/MusicGenerator/portfolio/static_test/images/piano_header.jpg (deflated 0%)
#   adding: content/MusicGenerator/portfolio/static_test/images/kern_web.png (deflated 4%)
#   adding: content/MusicGenerator/portfolio/static_test/images/dataset_header.jpg (deflated 0%)
#   adding: content/MusicGenerator/portfolio/static_test/images/Canada_folksong.jpg (deflated 1%)
#   adding: content/MusicGenerator/portfolio/static_test/images/Stephen_Foster.jpg (deflated 0%)
#   adding: content/MusicGenerator/portfolio/static_test/images/Bach.png (deflated 0%)
#   adding: content/MusicGenerator/portfolio/static_test/images/music.ico (deflated 79%)
#   adding: content/MusicGenerator/portfolio/static_test/images/China_folksong.jpg (deflated 12%)
#   adding: content/MusicGenerator/portfolio/static_test/css/ (stored 0%)
#   adding: content/MusicGenerator/portfolio/static_test/css/styles.css (deflated 87%)
#   adding: content/MusicGenerator/portfolio/static_test/music/ (stored 0%)
#   adding: content/MusicGenerator/portfolio/static_test/music/Canada_transformer.mid (deflated 47%)
#   adding: content/MusicGenerator/portfolio/static_test/music/China_transformer.mid (deflated 39%)
#   adding: content/MusicGenerator/portfolio/static_test/music/Germany_lstm.mid (deflated 77%)
#   adding: content/MusicGenerator/portfolio/static_test/music/accompaniment.mid (deflated 58%)
#   adding: content/MusicGenerator/portfolio/static_test/music/China_lstm.mid (deflated 71%)
#   adding: content/MusicGenerator/portfolio/static_test/music/Stephen_Foster_transformer.mid (deflated 51%)
#   adding: content/MusicGenerator/portfolio/static_test/music/Schubert_transformer.mid (deflated 38%)
#   adding: content/MusicGenerator/portfolio/static_test/music/Bach_dataset.mid (deflated 69%)
#   adding: content/MusicGenerator/portfolio/static_test/music/Canada_lstm.mid (deflated 80%)
#   adding: content/MusicGenerator/portfolio/static_test/music/Schubert_dataset.mid (deflated 73%)
#   adding: content/MusicGenerator/portfolio/static_test/music/China_dataset.mid (deflated 62%)
#   adding: content/MusicGenerator/portfolio/static_test/music/Germany_transformer.mid (deflated 49%)
#   adding: content/MusicGenerator/portfolio/static_test/music/Canada_dataset.mid (deflated 67%)
#   adding: content/MusicGenerator/portfolio/static_test/music/Bach_transformer.mid (deflated 42%)
#   adding: content/MusicGenerator/portfolio/static_test/music/output.mid (deflated 73%)
#   adding: content/MusicGenerator/portfolio/static_test/music/Stephen_Foster_lstm.mid (deflated 74%)
#   adding: content/MusicGenerator/portfolio/static_test/music/Schubert_lstm.mid (deflated 68%)
#   adding: content/MusicGenerator/portfolio/static_test/music/Germany_dataset.mid (deflated 41%)
#   adding: content/MusicGenerator/portfolio/static_test/music/Bach_lstm.mid (deflated 75%)
#   adding: content/MusicGenerator/portfolio/static_test/music/Stephen Foster_dataset.mid (deflated 81%)
#   adding: content/MusicGenerator/portfolio/db.sqlite3 (stored 0%)

# %%
from google.colab import files
files.download("/content/project.zip")
